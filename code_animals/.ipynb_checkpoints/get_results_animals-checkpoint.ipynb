# %% [markdown]
# # Generating the plots and tables for the Animals with Attributes 2 experiment

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as scs
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# ## Preparing the plots for Figure 2

# %%
folder = 'path/to/results/'

p = 1.
poss_n = [0, 10, 20, 30, 40, 50, 55, 59]
attr = 0

for attack_ind, attack_type in enumerate(['enforce_label', 'inputs_same', 'shuffle_labels',\
                                                  'blured', 'pixels', 'RGB']):
    sigma = [0,0,0,6,30,0][attack_ind]
    
    errs = np.zeros([8,100])
    errs_zero = np.zeros([8,100])
    errs_inf = np.zeros([8,100])
    errs_svm = np.zeros([8,100])
    errs_detector = np.zeros([8,100])
    errs_robust_log_regr_soft = np.zeros([8,100])
    errs_robust_probs = np.zeros([8,100])
    errs_geometric_median = np.zeros([8,100])
    errs_component_median = np.zeros([8,100])
    errs_batch_norm = np.zeros([8,100])


    for l, n in enumerate(poss_n):
        if l == 0:
            p1 = 0
            n1 = 0
            sigma1 = 0
            attack_type1 = 'none'
            for i in range(100):
                errs[l,i] = np.load(folder + 'errs_' + attack_type1 \
                                   + '_' + str(sigma1) + '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_zero[l,i] = np.load(folder + 'errs_zero_' + attack_type1 \
                                   + '_' + str(sigma1) + '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_inf[l,i] = np.load(folder + 'errs_inf_' + attack_type1 \
                               + '_' + str(sigma1) + '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_robust_log_regr_soft[l,i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type1 \
                                  + '_' + str(sigma1)+ '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_robust_probs[l,i] = np.load(folder + 'errs_robust_probs_' + attack_type1 \
                              + '_' + str(sigma1)+ '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_geometric_median[l,i] = np.load(folder + 'errs_geometric_median_' + attack_type1 \
                              + '_' + str(sigma1)+ '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_component_median[l,i] = np.load(folder + 'errs_component_median_' + attack_type1 \
                              + '_' + str(sigma1)+ '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_batch_norm[l,i] = np.load(folder + 'errs_batch_norm_' + attack_type1 \
                              + '_' + str(sigma1)+ '_' + str(n1) + '_' + str(p1) + '_' + str(i) + '_' + str(attr) + '.npy')

        else: 
            for i in range(100):
                errs[l,i] = np.load(folder + 'errs_' + attack_type \
                                    + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_zero[l,i] = np.load(folder + 'errs_zero_' + attack_type \
                                   + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_inf[l,i] = np.load(folder + 'errs_inf_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_robust_log_regr_soft[l,i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_robust_probs[l,i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_geometric_median[l,i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_component_median[l,i] = np.load(folder + 'errs_component_median_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')
                errs_batch_norm[l,i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')



    # Estimates for the mean
    means_vec = np.mean(errs, axis = 1)
    means_vec_zero = np.mean(errs_zero, axis = 1)
    means_vec_inf = np.mean(errs_inf, axis = 1)
    means_vec_robust_log_regr_soft = np.mean(errs_robust_log_regr_soft, axis = 1)
    means_vec_robust_probs = np.mean(errs_robust_probs, axis = 1)
    means_vec_geometric_median = np.mean(errs_geometric_median, axis = 1)
    means_vec_component_median = np.mean(errs_component_median, axis = 1)
    means_vec_batch_norm = np.mean(errs_batch_norm, axis = 1)

    # Estimates for the standard error
    stds_vec = np.std(errs, axis = 1)
    stds_vec_zero = np.std(errs_zero, axis = 1)
    stds_vec_inf = np.std(errs_inf, axis = 1)
    stds_vec_robust_log_regr_soft = np.std(errs_robust_log_regr_soft, axis = 1)
    stds_vec_robust_probs = np.std(errs_robust_probs, axis = 1)
    stds_vec_geometric_median = np.std(errs_geometric_median, axis = 1)
    stds_vec_component_median = np.std(errs_component_median, axis = 1)
    stds_vec_batch_norm = np.std(errs_batch_norm, axis = 1)
    
    
    plt.figure(figsize=(12,9))
    #plt.style.use('ggplot')
    plt.errorbar(x = poss_n, y = means_vec, yerr = stds_vec, color = 'green', label = 'Ours', linewidth=5)
    plt.errorbar(x = poss_n, y = means_vec_zero, yerr = stds_vec_zero, color = 'red', label = 'Reference only')
    plt.errorbar(x = poss_n, y = means_vec_inf, yerr = stds_vec_inf, color = 'blue', label = 'All data')
    plt.errorbar(x = poss_n, y = means_vec_robust_log_regr_soft, yerr = stds_vec_robust_log_regr_soft, color = 'pink', label = 'Pregibon et al.')
    plt.errorbar(x = poss_n, y = means_vec_robust_probs, yerr = stds_vec_robust_probs, color = 'black', label = 'Median of probs')
    plt.errorbar(x = poss_n, y = means_vec_geometric_median, yerr = stds_vec_geometric_median, color = 'grey', label = 'Feng et al.')
    plt.errorbar(x = poss_n, y = means_vec_component_median, yerr = stds_vec_component_median, color = 'purple', label = 'Yin et al.')
    plt.errorbar(x = poss_n, y = means_vec_batch_norm, yerr = stds_vec_batch_norm, color = 'magenta', label = 'Batch norm')




    plt.legend(loc = 2, fontsize = 24)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
    plt.xlabel('Number of corrupted tasks', fontsize = 30)
    plt.ylabel('Average classification error', fontsize = 30)

    ax=plt.gca()
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.set_facecolor('xkcd:white')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_linewidth(2)
    ax.spines['left'].set_linewidth(2)
    plt.savefig("mean_error_" + attack_type + '_' + str(int(p)) + '_' + str(attr) + '.pdf')
    plt.show()

# %% [markdown]
# ## Preparing the tables, summed over all corruptions

# %% [markdown]
# For p = 1:

# %%
folder = 'path/to/results/'

p_value = 0.01

def_p = 1.
poss_n = [0, 10, 20, 30, 40, 50, 55, 59]

table_wins = np.zeros((7,8))
table_draws = np.zeros((7,8))
table_losses = np.zeros((7,8))

for baseline_ind in range(7):
    for n_ind, n in enumerate(poss_n):
        
        if n == 0:
            p = 0
            sigma = 0
            attack_type = 'none'
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):

                errs = np.zeros(100)
                errs_baseline = np.zeros(100)

                for i in range(100):
                    errs[i] = np.load(folder + 'errs_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 0:
                        errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 1:
                        errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 2:
                        errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 3:
                        errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 4:
                        errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 5:
                        errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 6:
                        errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                    losses += 1
                elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                    wins += 1
                else:
                    draws += 1
                
            
            
            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
            print(baseline_ind, n, wins, draws, losses)
        else:
            p = def_p
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):
                for attack_ind, attack_type in enumerate(['enforce_label', 'inputs_same', 'shuffle_labels',\
                                              'blured', 'pixels', 'RGB']):
                    
                    sigma = [0, 0, 0, 6, 30, 0][attack_ind]
                    
                    errs = np.zeros(100)
                    errs_baseline = np.zeros(100)
                    
                    for i in range(100):
                        errs[i] = np.load(folder + 'errs_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 0:
                            errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                               + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 1:
                            errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 2:
                            errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 3:
                            errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 4:
                            errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 5:
                            errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 6:
                            errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                        losses += 1
                    elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                        wins += 1
                    else:
                        draws += 1

                    

            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
            
            print(baseline_ind, n, wins, draws, losses)

# %% [markdown]
# Print the result in a format appropriate for a latex table

# %%
for i in range(7):
    for j in range(8):
        if j < 7:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' & ', sep='', end='')
        else:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' \\\\', sep='', end='\n')

# %% [markdown]
# For p = 0.5:

# %%
folder = 'path/to/results/'

def_p = 0.5
poss_n = [0, 10, 20, 30, 40, 50, 55, 59]

table_wins = np.zeros((7,8))
table_draws = np.zeros((7,8))
table_losses = np.zeros((7,8))

for baseline_ind in range(7):
    for n_ind, n in enumerate(poss_n):
        
        if n == 0:
            p = 0
            sigma = 0
            attack_type = 'none'
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):

                errs = np.zeros(100)
                errs_baseline = np.zeros(100)

                for i in range(100):
                    errs[i] = np.load(folder + 'errs_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 0:
                        errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 1:
                        errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 2:
                        errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 3:
                        errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 4:
                        errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 5:
                        errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 6:
                        errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                    losses += 1
                elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                    wins += 1
                else:
                    draws += 1
            
            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
        else:
            p = def_p
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):
                for attack_ind, attack_type in enumerate(['enforce_label', 'inputs_same', 'shuffle_labels',\
                                              'blured', 'pixels', 'RGB']):
                    
                    sigma = [0, 0, 0, 6, 30, 0][attack_ind]
                    
                    errs = np.zeros(100)
                    errs_baseline = np.zeros(100)
                    
                    for i in range(100):
                        errs[i] = np.load(folder + 'errs_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 0:
                            errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                               + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 1:
                            errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 2:
                            errs_baseline[i] = np.load(folder2 + 'errs_robust_probs_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 3:
                            errs_baseline[i] = np.load(folder2 + 'errs_geometric_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 4:
                            errs_baseline[i] = np.load(folder2 + 'errs_component_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 5:
                            errs_baseline[i] = np.load(folder2 + 'errs_robust_log_regr_soft_' + attack_type \
                                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 6:
                            errs_baseline[i] = np.load(folder2 + 'errs_batch_norm_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                        losses += 1
                    elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                        wins += 1
                    else:
                        draws += 1
            
            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
            
            print(baseline_ind, n, wins, draws, losses)

# %%
for i in range(7):
    for j in range(8):
        if j < 7:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' & ', sep='', end='')
        else:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' \\\\', sep='', end='\n')

# %% [markdown]
# For p = 0.2:

# %%
folder = 'path/to/result/'
def_p = 0.2
poss_n = [0, 10, 20, 30, 40, 50, 55, 59]

table_wins = np.zeros((7,8))
table_draws = np.zeros((7,8))
table_losses = np.zeros((7,8))

for baseline_ind in range(7):
    for n_ind, n in enumerate(poss_n):
        
        if n == 0:
            p = 0
            sigma = 0
            attack_type = 'none'
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):

                errs = np.zeros(100)
                errs_baseline = np.zeros(100)

                for i in range(100):
                    errs[i] = np.load(folder + 'errs_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 0:
                        errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 1:
                        errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 2:
                        errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 3:
                        errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 4:
                        errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 5:
                        errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if baseline_ind == 6:
                        errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                    losses += 1
                elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                    wins += 1
                else:
                    draws += 1
            
            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
        else:
            p = def_p
            
            wins = 0
            draws = 0
            losses = 0
            
            for attr in range(85):
                for attack_ind, attack_type in enumerate(['enforce_label', 'inputs_same', 'shuffle_labels',\
                                              'blured', 'pixels', 'RGB']):
                    
                    sigma = [0, 0, 0, 6, 30, 0][attack_ind]
                    
                    errs = np.zeros(100)
                    errs_baseline = np.zeros(100)
                    
                    for i in range(100):
                        errs[i] = np.load(folder + 'errs_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 0:
                            errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                               + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 1:
                            errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                           + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 2:
                            errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 3:
                            errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 4:
                            errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 5:
                            errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                        if baseline_ind == 6:
                            errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                          + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                    if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                        losses += 1
                    elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                        wins += 1
                    else:
                        draws += 1
            
            table_wins[baseline_ind, n_ind] = wins
            table_draws[baseline_ind, n_ind] = draws
            table_losses[baseline_ind, n_ind] = losses
            
            print(baseline_ind, n, wins, draws, losses)

# %%
for i in range(7):
    for j in range(8):
        if j < 7:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' & ', sep='', end='')
        else:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' \\\\', sep='', end='\n')

# %% [markdown]
# ## Example code for obtaining the attack-specific tables:

# %%
folder = 'path/to/results/'

p = 1.
attack_type = 'enforce_label'
poss_n = [10, 20, 30, 40, 50, 55, 59]

table_wins = np.zeros((7,8))
table_draws = np.zeros((7,8))
table_losses = np.zeros((7,8))

for baseline_ind in range(7):
    for n_ind, n in enumerate(poss_n):

        wins = 0
        draws = 0
        losses = 0

        for attr in range(85):

            sigma = [0, 0, 0, 6, 30, 0][attack_ind]

            errs = np.zeros(100)
            errs_baseline = np.zeros(100)

            for i in range(100):
                errs[i] = np.load(folder + 'errs_' + attack_type \
                                   + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 0:
                    errs_baseline[i] = np.load(folder + 'errs_zero_' + attack_type \
                                       + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 1:
                    errs_baseline[i] = np.load(folder + 'errs_inf_' + attack_type \
                                   + '_' + str(sigma) + '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 2:
                    errs_baseline[i] = np.load(folder + 'errs_robust_probs_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 3:
                    errs_baseline[i] = np.load(folder + 'errs_geometric_median_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 4:
                    errs_baseline[i] = np.load(folder + 'errs_component_median_' + attack_type \
                              + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 5:
                    errs_baseline[i] = np.load(folder + 'errs_robust_log_regr_soft_' + attack_type \
                                      + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

                if baseline_ind == 6:
                    errs_baseline[i] = np.load(folder + 'errs_batch_norm_' + attack_type \
                                  + '_' + str(sigma)+ '_' + str(n) + '_' + str(p) + '_' + str(i) + '_' + str(attr) + '.npy')

            if (np.mean(errs) > np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs) - np.mean(errs_baseline))):
                losses += 1
            elif (np.mean(errs) < np.mean(errs_baseline)) and ((np.std(errs) + np.std(errs_baseline)) < (np.mean(errs_baseline) - np.mean(errs))):
                wins += 1
            else:
                draws += 1

        table_wins[baseline_ind, n_ind] = wins
        table_draws[baseline_ind, n_ind] = draws
        table_losses[baseline_ind, n_ind] = losses

        print(baseline_ind, n, wins, draws, losses)

# %%
for i in range(7):
    for j in range(7):
        if j < 6:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' & ', sep='', end='')
        else:
            print(int(table_wins[i,j]), '/', int(table_draws[i,j]), '/', int(table_losses[i,j]), ' \\\\', sep='', end='\n')
